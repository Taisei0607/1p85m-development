# %%
import FSW0000

# %%
port = "/dev/tty.usbmodem11401" # ls /dev/tty*で確認

sg = FSW0000.FSW0000(port)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/tty.usbmodem11401'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 port = "/dev/tty.usbmodem11401" # ls /dev/tty*で確認
# ----> 3 sg = FSW0000.FSW0000(port)
#
# File ~/Desktop/Python関係/FSW0000.py:9, in FSW0000.__init__(self, port)
#       7 def __init__(self,port):
# ----> 9     self.ser = serial.Serial(port)
#
# ...

# %%
sg.power_set(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sg.power_set(3)
#
# NameError: name 'sg' is not defined

# %%
sg.freq_set(12) # 周波数の指定
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sg.freq_set(12) # 周波数の指定
#
# NameError: name 'sg' is not defined

# %%
sg.output_on() # rf出力をonにする
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sg.output_on() # rf出力をonにする
#
# NameError: name 'sg' is not defined

# %%
sg.output_off() # rf出力をoffにする
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sg.output_off() # rf出力をoffにする
#
# NameError: name 'sg' is not defined
